# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '31e1f021-d108-4d24-a54e-3b0d6286ca3b',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-10-26T13:59:05.049Z', 'error_code': 0, 'error_message': None, 'elapsed': 44, 'credit_count': 1, 'notice': None, 'total_count': 9863}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11788, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19773265, 'total_supply': 19773265, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-26T13:57:00.000Z', 'quote': {'USD': {'price': 66856.02291297972, 'volume_24h': 38596325500.92779, 'volume_change_24h': 28.7451, 'percent_change_1h': -0.12802243, 'percent_change_24h': -1.97090612, 'percent_change_7d': -1.84290562, 'percent_change_30d': 3.87669976, 'percent_change_60d': 7.31216569, 'percent_change_90d': -1.69220838, 'market_cap': 1321961857904.42, 'market_cap_dominance': 58.2385, 'fully_diluted_market_cap': 1403976481172.57, 'tvl': None, 'last_updated': '2024-10-26T13:57:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9450, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120399251.19061367, 'total_supply': 120399251.19061367, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-26T13:57:00.000Z', 'quote': {'USD': {'price': 2464.0573113607597, 'volume_24h': 21170745480.38974, 'volume_change_24h': 27.0526, 'percent_change_1h': -0.19118133, 'percent_change_24h': -3.22724079, 'percent_change_7d': -6.53283636, 'percent_change_30d': -5.92129664, 'percent_change_60d': -5.75532806, 'percent_change_90d': -24.77925262, 'market_cap': 296670655178.5923, 'market_cap_dominance': 13.0697, 'fully_diluted_market_cap': 296670655178.59, 'tvl': None, 'last_updated': '2024-10-26T13:57:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101582, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120304469780.02702, 'total_supply': 121337925865.3336, 'platform': {'id' ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#See all the columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11788
# 1    1027      Ethereum    ETH      ethereum              9450
# 2     825   Tether USDt   USDT        tether            101582
# 3    1839           BNB    BNB           bnb              2271
# 4    5426        Solana    SOL        solana               774
# 5    3408          USDC   USDC      usd-coin             22671
# 6      52           XRP    XRP           xrp              1411
# 7      74      Dogecoin   DOGE      dogecoin              1088
# 8    1958          TRON    TRX          tron              1058
# 9   11419       Toncoin    TON       toncoin               586
# 10   2010       Cardano    ADA       cardano              1302
# 11   5805     Avalanche   AVAX     avalanche               794
# 12   5994     Shiba Inu   SHIB     shiba-inu               892
# 13   1831  Bitcoin Cash    BCH  bitcoin-cash               938
# 14   1975     Chainlink   LINK     chainlink              1865
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2017-07-23T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 14  [platform, defi, oracles, smart-contracts, sub...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977326e+07  1.977326e+07            False       NaN         1
# 1         1.203993e+08  1.203993e+08             True       NaN         2
# 2         1.203045e+11  1.213379e+11             True       NaN         3
# 3         1.459312e+08  1.459312e+08            False       NaN         4
# 4         4.701959e+08  5.872580e+08             True       NaN         5
# 5         3.468540e+10  3.468540e+10            False       NaN         6
# 6         5.681186e+10  9.998707e+10            False       NaN         7
# 7         1.465281e+11  1.465281e+11             True       NaN         8
# 8         8.648639e+10  8.648645e+10             True       NaN         9
# 9         2.541872e+09  5.113888e+09             True       NaN        10
# 10        3.498097e+10  4.499512e+10            False       NaN        11
# 11        4.070161e+08  4.470192e+08            False       NaN        12
# 12        5.892671e+14  5.895183e+14            False       NaN        13
# 13        1.977958e+07  1.977958e+07            False       NaN        14
# 14        6.268500e+08  1.000000e+09            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       7.165966e+10              1.180816e+10      None
# 9                       3.414167e+09              1.671650e+10      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-26T13:57:00.000Z     66856.022913          3.859633e+10
# 1   2024-10-26T13:57:00.000Z      2464.057311          2.117075e+10
# 2   2024-10-26T13:56:00.000Z         0.998720          7.477038e+10
# 3   2024-10-26T13:56:00.000Z       580.315654          1.713114e+09
# 4   2024-10-26T13:56:00.000Z       168.061327          4.858859e+09
# 5   2024-10-26T13:56:00.000Z         0.999849          9.429359e+09
# 6   2024-10-26T13:56:00.000Z         0.510815          1.290135e+09
# 7   2024-10-26T13:56:00.000Z         0.133472          1.359964e+09
# 8   2024-10-26T13:56:00.000Z         0.164781          4.905614e+08
# 9   2024-10-26T13:56:00.000Z         4.896218          3.037345e+08
# 10  2024-10-26T13:56:00.000Z         0.328409          4.406555e+08
# 11  2024-10-26T13:56:00.000Z        25.304915          3.736421e+08
# 12  2024-10-26T13:56:00.000Z         0.000017          3.469852e+08
# 13  2024-10-26T13:56:00.000Z       349.112104          2.981911e+08
# 14  2024-10-26T13:56:00.000Z        10.971330          4.005355e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       28.7451                    -0.128022
# 1                       27.0526                    -0.191181
# 2                       32.6200                     0.000773
# 3                       14.7866                    -0.465811
# 4                       47.5175                    -0.493256
# 5                       36.9800                     0.004008
# 6                       60.8117                    -0.605300
# 7                        9.1728                    -0.777690
# 8                       31.8000                     0.109284
# 9                       87.9414                    -0.520076
# 10                      73.8908                    -0.570765
# 11                      99.8836                    -1.065244
# 12                      64.9066                    -0.805284
# 13                     -18.7368                    -0.891415
# 14                      58.2592                    -1.044147
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -1.970906                    -1.842906
# 1                      -3.227241                    -6.532836
# 2                      -0.068594                    -0.124557
# 3                      -1.964980                    -2.701969
# 4                      -3.595915                     8.546073
# 5                      -0.005706                    -0.012615
# 6                      -2.633073                    -6.160366
# 7                      -3.397658                    -7.836575
# 8                      -1.055548                     4.493125
# 9                      -2.760161                    -6.549500
# 10                     -4.914951                    -6.359792
# 11                     -4.581589                    -9.255014
# 12                     -4.928365                   -12.344292
# 13                     -5.966825                    -3.797594
# 14                     -7.616400                    -3.361355
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       3.876700                      7.312166
# 1                      -5.921297                     -5.755328
# 2                      -0.144695                     -0.139007
# 3                      -2.101571                      4.400169
# 4                      10.768371                      8.483293
# 5                      -0.033495                     -0.018198
# 6                     -13.265045                    -13.994802
# 7                      16.676544                     27.907745
# 8                       8.118377                      2.219292
# 9                     -15.411108                    -10.610889
# 10                    -17.156207                    -10.073523
# 11                    -11.146309                     -1.714535
# 12                     -1.570968                     16.760619
# 13                     -0.075975                      2.450492
# 14                    -10.288609                     -5.557986
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -1.692208          1.321962e+12
# 1                     -24.779253          2.966707e+11
# 2                      -0.121315          1.201504e+11
# 3                      -0.299564          8.468613e+10
# 4                      -9.844958          7.902175e+10
# 5                      -0.006380          3.468018e+10
# 6                     -15.142837          2.902032e+10
# 7                       2.019461          1.955733e+10
# 8                      19.827110          1.425132e+10
# 9                     -25.257047          1.244556e+10
# 10                    -20.262069          1.148805e+10
# 11                     -8.374348          1.029951e+10
# 12                     -0.591164          9.897701e+09
# 13                    -12.455260          6.905291e+09
# 14                    -19.242267          6.877378e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          58.2385                        1.403976e+12
# 1                          13.0697                        2.966707e+11
# 2                           5.2896                        1.211826e+11
# 3                           3.7283                        8.468613e+10
# 4                           3.4789                        9.869536e+10
# 5                           1.5268                        3.468018e+10
# 6                           1.2778                        5.108145e+10
# 7                           0.8610                        1.955733e+10
# 8                           0.6275                        1.425133e+10
# 9                           0.5479                        2.503871e+10
# 10                          0.5058                        1.477838e+10
# 11                          0.4535                        1.811196e+10
# 12                          0.4357                        9.901922e+09
# 13                          0.3040                        7.331354e+09
# 14                          0.3027                        1.097133e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-26T13:57:00.000Z          NaN           NaN
# 1           None  2024-10-26T13:57:00.000Z          NaN           NaN
# 2           None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
# 3           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 4           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 5           None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
# 6           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 7           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 8           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 9           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 10          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 11          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 12          None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
# 13          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 14          None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2024-10-26 16:59:12.687480
# 1  2024-10-26 16:59:12.687480
# 2  2024-10-26 16:59:12.687480
# 3  2024-10-26 16:59:12.687480
# 4  2024-10-26 16:59:12.687480
# 5  2024-10-26 16:59:12.687480
# 6  2024-10-26 16:59:12.687480
# 7  2024-10-26 16:59:12.687480
# 8  2024-10-26 16:59:12.687480
# 9  2024-10-26 16:59:12.687480
# 10 2024-10-26 16:59:12.687480
# 11 2024-10-26 16:59:12.687480
# 12 2024-10-26 16:59:12.687480
# 13 2024-10-26 16:59:12.687480
# 14 2024-10-26 16:59:12.687480

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '31e1f021-d108-4d24-a54e-3b0d6286ca3b',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    

    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = pd.concat([df, df2], ignore_index=True)

# %%
import os 
from time import time
from time import sleep

# max per day = 333
for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)
exit()

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11788
# 1    1027      Ethereum    ETH      ethereum              9450
# 2     825   Tether USDt   USDT        tether            101582
# 3    1839           BNB    BNB           bnb              2271
# 4    5426        Solana    SOL        solana               774
# 5    3408          USDC   USDC      usd-coin             22671
# 6      52           XRP    XRP           xrp              1411
# 7      74      Dogecoin   DOGE      dogecoin              1088
# 8    1958          TRON    TRX          tron              1058
# 9   11419       Toncoin    TON       toncoin               586
# 10   2010       Cardano    ADA       cardano              1302
# 11   5805     Avalanche   AVAX     avalanche               794
# 12   5994     Shiba Inu   SHIB     shiba-inu               892
# 13   1831  Bitcoin Cash    BCH  bitcoin-cash               938
# 14   1975     Chainlink   LINK     chainlink              1865
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2017-07-23T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 14  [platform, defi, oracles, smart-contracts, sub...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977326e+07  1.977326e+07            False       NaN         1
# 1         1.203993e+08  1.203993e+08             True       NaN         2
# 2         1.203045e+11  1.213379e+11             True       NaN         3
# 3         1.459312e+08  1.459312e+08            False       NaN         4
# 4         4.701959e+08  5.872580e+08             True       NaN         5
# 5         3.468540e+10  3.468540e+10            False       NaN         6
# 6         5.681186e+10  9.998707e+10            False       NaN         7
# 7         1.465281e+11  1.465281e+11             True       NaN         8
# 8         8.648639e+10  8.648645e+10             True       NaN         9
# 9         2.541872e+09  5.113888e+09             True       NaN        10
# 10        3.498097e+10  4.499512e+10            False       NaN        11
# 11        4.070161e+08  4.470192e+08            False       NaN        12
# 12        5.892671e+14  5.895183e+14            False       NaN        13
# 13        1.977958e+07  1.977958e+07            False       NaN        14
# 14        6.268500e+08  1.000000e+09            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       7.165966e+10              1.180816e+10      None
# 9                       3.414167e+09              1.671650e+10      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-26T13:57:00.000Z     66856.022913          3.859633e+10
# 1   2024-10-26T13:57:00.000Z      2464.057311          2.117075e+10
# 2   2024-10-26T13:56:00.000Z         0.998720          7.477038e+10
# 3   2024-10-26T13:56:00.000Z       580.315654          1.713114e+09
# 4   2024-10-26T13:56:00.000Z       168.061327          4.858859e+09
# 5   2024-10-26T13:56:00.000Z         0.999849          9.429359e+09
# 6   2024-10-26T13:56:00.000Z         0.510815          1.290135e+09
# 7   2024-10-26T13:56:00.000Z         0.133472          1.359964e+09
# 8   2024-10-26T13:56:00.000Z         0.164781          4.905614e+08
# 9   2024-10-26T13:56:00.000Z         4.896218          3.037345e+08
# 10  2024-10-26T13:56:00.000Z         0.328409          4.406555e+08
# 11  2024-10-26T13:56:00.000Z        25.304915          3.736421e+08
# 12  2024-10-26T13:56:00.000Z         0.000017          3.469852e+08
# 13  2024-10-26T13:56:00.000Z       349.112104          2.981911e+08
# 14  2024-10-26T13:56:00.000Z        10.971330          4.005355e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       28.7451                    -0.128022
# 1                       27.0526                    -0.191181
# 2                       32.6200                     0.000773
# 3                       14.7866                    -0.465811
# 4                       47.5175                    -0.493256
# 5                       36.9800                     0.004008
# 6                       60.8117                    -0.605300
# 7                        9.1728                    -0.777690
# 8                       31.8000                     0.109284
# 9                       87.9414                    -0.520076
# 10                      73.8908                    -0.570765
# 11                      99.8836                    -1.065244
# 12                      64.9066                    -0.805284
# 13                     -18.7368                    -0.891415
# 14                      58.2592                    -1.044147
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -1.970906                    -1.842906
# 1                      -3.227241                    -6.532836
# 2                      -0.068594                    -0.124557
# 3                      -1.964980                    -2.701969
# 4                      -3.595915                     8.546073
# 5                      -0.005706                    -0.012615
# 6                      -2.633073                    -6.160366
# 7                      -3.397658                    -7.836575
# 8                      -1.055548                     4.493125
# 9                      -2.760161                    -6.549500
# 10                     -4.914951                    -6.359792
# 11                     -4.581589                    -9.255014
# 12                     -4.928365                   -12.344292
# 13                     -5.966825                    -3.797594
# 14                     -7.616400                    -3.361355
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       3.876700                      7.312166
# 1                      -5.921297                     -5.755328
# 2                      -0.144695                     -0.139007
# 3                      -2.101571                      4.400169
# 4                      10.768371                      8.483293
# 5                      -0.033495                     -0.018198
# 6                     -13.265045                    -13.994802
# 7                      16.676544                     27.907745
# 8                       8.118377                      2.219292
# 9                     -15.411108                    -10.610889
# 10                    -17.156207                    -10.073523
# 11                    -11.146309                     -1.714535
# 12                     -1.570968                     16.760619
# 13                     -0.075975                      2.450492
# 14                    -10.288609                     -5.557986
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -1.692208          1.321962e+12
# 1                     -24.779253          2.966707e+11
# 2                      -0.121315          1.201504e+11
# 3                      -0.299564          8.468613e+10
# 4                      -9.844958          7.902175e+10
# 5                      -0.006380          3.468018e+10
# 6                     -15.142837          2.902032e+10
# 7                       2.019461          1.955733e+10
# 8                      19.827110          1.425132e+10
# 9                     -25.257047          1.244556e+10
# 10                    -20.262069          1.148805e+10
# 11                     -8.374348          1.029951e+10
# 12                     -0.591164          9.897701e+09
# 13                    -12.455260          6.905291e+09
# 14                    -19.242267          6.877378e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          58.2385                        1.403976e+12
# 1                          13.0697                        2.966707e+11
# 2                           5.2896                        1.211826e+11
# 3                           3.7283                        8.468613e+10
# 4                           3.4789                        9.869536e+10
# 5                           1.5268                        3.468018e+10
# 6                           1.2778                        5.108145e+10
# 7                           0.8610                        1.955733e+10
# 8                           0.6275                        1.425133e+10
# 9                           0.5479                        2.503871e+10
# 10                          0.5058                        1.477838e+10
# 11                          0.4535                        1.811196e+10
# 12                          0.4357                        9.901922e+09
# 13                          0.3040                        7.331354e+09
# 14                          0.3027                        1.097133e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-26T13:57:00.000Z          NaN           NaN
# 1           None  2024-10-26T13:57:00.000Z          NaN           NaN
# 2           None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
# 3           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 4           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 5           None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
# 6           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 7           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 8           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 9           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 10          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 11          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 12          None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
# 13          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 14          None  2024-10-26T13:56:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2024-10-26 16:59:12.687480
# 1  2024-10-26 16:59:12.687480
# 2  2024-10-26 16:59:12.687480
# 3  2024-10-26 16:59:12.687480
# 4  2024-10-26 16:59:12.687480
# 5  2024-10-26 16:59:12.687480
# 6  2024-10-26 16:59:12.687480
# 7  2024-10-26 16:59:12.687480
# 8  2024-10-26 16:59:12.687480
# 9  2024-10-26 16:59:12.687480
# 10 2024-10-26 16:59:12.687480
# 11 2024-10-26 16:59:12.687480
# 12 2024-10-26 16:59:12.687480
# 13 2024-10-26 16:59:12.687480
# 14 2024-10-26 16:59:12.687480

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11788
# 1    1027      Ethereum    ETH      ethereum              9450
# 2     825   Tether USDt   USDT        tether            101582
# 3    1839           BNB    BNB           bnb              2271
# 4    5426        Solana    SOL        solana               774
# 5    3408          USDC   USDC      usd-coin             22671
# 6      52           XRP    XRP           xrp              1411
# 7      74      Dogecoin   DOGE      dogecoin              1088
# 8    1958          TRON    TRX          tron              1058
# 9   11419       Toncoin    TON       toncoin               586
# 10   2010       Cardano    ADA       cardano              1302
# 11   5805     Avalanche   AVAX     avalanche               794
# 12   5994     Shiba Inu   SHIB     shiba-inu               892
# 13   1831  Bitcoin Cash    BCH  bitcoin-cash               938
# 14   1975     Chainlink   LINK     chainlink              1865
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2017-07-23T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 10  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 11  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 12      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 13  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 14  [platform, defi, oracles, smart-contracts, sub...                NaN
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19773265.00000        19773265.00000            False       NaN
# 1        120399251.19061       120399251.19061             True       NaN
# 2     120304469780.02702    121337925865.33360             True       NaN
# 3        145931156.82618       145931156.82618            False       NaN
# 4        470195908.16925       587258012.97414             True       NaN
# 5      34685401489.12111     34685401489.12111            False       NaN
# 6      56811862950.00000     99987068281.00000            False       NaN
# 7     146528146383.70523    146528146383.70523             True       NaN
# 8      86486389218.02266     86486448831.50139             True       NaN
# 9       2541871972.39158      5113887884.26554             True       NaN
# 10     34980974699.72432     44995121858.38750            False       NaN
# 11       407016095.98049       447019195.98049            False       NaN
# 12 589267050673619.62500 589518319120127.12500            False       NaN
# 13        19779581.25000        19779581.25000            False       NaN
# 14       626849970.45279      1000000000.00000            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                 71659659264.00000         11808155994.47425
# 9         10                  3414166606.00000         16716503235.72592
# 10        11                               NaN                       NaN
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2024-10-26T13:57:00.000Z      66856.02291     38596325500.92779
# 1       None  2024-10-26T13:57:00.000Z       2464.05731     21170745480.38974
# 2       None  2024-10-26T13:56:00.000Z          0.99872     74770377043.16022
# 3       None  2024-10-26T13:56:00.000Z        580.31565      1713114083.96186
# 4       None  2024-10-26T13:56:00.000Z        168.06133      4858858964.35888
# 5       None  2024-10-26T13:56:00.000Z          0.99985      9429359422.59828
# 6       None  2024-10-26T13:56:00.000Z          0.51081      1290135069.62919
# 7       None  2024-10-26T13:56:00.000Z          0.13347      1359963674.93037
# 8       None  2024-10-26T13:56:00.000Z          0.16478       490561387.31677
# 9       None  2024-10-26T13:56:00.000Z          4.89622       303734525.70555
# 10      None  2024-10-26T13:56:00.000Z          0.32841       440655525.16997
# 11      None  2024-10-26T13:56:00.000Z         25.30491       373642070.67136
# 12      None  2024-10-26T13:56:00.000Z          0.00002       346985244.88926
# 13      None  2024-10-26T13:56:00.000Z        349.11210       298191053.30706
# 14      None  2024-10-26T13:56:00.000Z         10.97133       400535454.06102
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      28.74510                     -0.12802
# 1                      27.05260                     -0.19118
# 2                      32.62000                      0.00077
# 3                      14.78660                     -0.46581
# 4                      47.51750                     -0.49326
# 5                      36.98000                      0.00401
# 6                      60.81170                     -0.60530
# 7                       9.17280                     -0.77769
# 8                      31.80000                      0.10928
# 9                      87.94140                     -0.52008
# 10                     73.89080                     -0.57076
# 11                     99.88360                     -1.06524
# 12                     64.90660                     -0.80528
# 13                    -18.73680                     -0.89142
# 14                     58.25920                     -1.04415
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -1.97091                     -1.84291
# 1                       -3.22724                     -6.53284
# 2                       -0.06859                     -0.12456
# 3                       -1.96498                     -2.70197
# 4                       -3.59591                      8.54607
# 5                       -0.00571                     -0.01261
# 6                       -2.63307                     -6.16037
# 7                       -3.39766                     -7.83657
# 8                       -1.05555                      4.49312
# 9                       -2.76016                     -6.54950
# 10                      -4.91495                     -6.35979
# 11                      -4.58159                     -9.25501
# 12                      -4.92836                    -12.34429
# 13                      -5.96683                     -3.79759
# 14                      -7.61640                     -3.36136
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                        3.87670                       7.31217
# 1                       -5.92130                      -5.75533
# 2                       -0.14470                      -0.13901
# 3                       -2.10157                       4.40017
# 4                       10.76837                       8.48329
# 5                       -0.03350                      -0.01820
# 6                      -13.26504                     -13.99480
# 7                       16.67654                      27.90774
# 8                        8.11838                       2.21929
# 9                      -15.41111                     -10.61089
# 10                     -17.15621                     -10.07352
# 11                     -11.14631                      -1.71454
# 12                      -1.57097                      16.76062
# 13                      -0.07598                       2.45049
# 14                     -10.28861                      -5.55799
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       -1.69221   1321961857904.41992
# 1                      -24.77925    296670655178.59229
# 2                       -0.12132    120150431732.70226
# 3                       -0.29956     84686134766.01799
# 4                       -9.84496     79021748292.96049
# 5                       -0.00638     34680180982.83368
# 6                      -15.14284     29020323658.24170
# 7                        2.01946     19557334673.39315
# 8                       19.82711     14251320558.51506
# 9                      -25.25705     12445558742.39164
# 10                     -20.26207     11488051103.22049
# 11                      -8.37435     10299507570.04461
# 12                      -0.59116      9897701415.81346
# 13                     -12.45526      6905291225.46440
# 14                     -19.24227      6877377791.37989
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         58.23850                 1403976481172.57007
# 1                         13.06970                  296670655178.59003
# 2                          5.28960                  121182564579.08000
# 3                          3.72830                   84686134766.02000
# 4                          3.47890                   98695360971.88000
# 5                          1.52680                   34680180982.83000
# 6                          1.27780                   51081450512.87000
# 7                          0.86100                   19557334673.39000
# 8                          0.62750                   14251330381.69000
# 9                          0.54790                   25038708777.20000
# 10                         0.50580                   14778384652.87000
# 11                         0.45350                   18111960245.29000
# 12                         0.43570                    9901921879.28000
# 13                         0.30400                    7331354182.98000
# 14                         0.30270                   10971329848.53000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-26T13:57:00.000Z          NaN           NaN
# 1           None  2024-10-26T13:57:00.000Z          NaN           NaN
# 2           None  2024-10-26T13:56:00.000Z   1027.00000      Ethereum
# 3           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 4           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 5           None  2024-10-26T13:56:00.000Z   1027.00000      Ethereum
# 6           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 7           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 8           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 9           None  2024-10-26T13:56:00.000Z          NaN           NaN
# 10          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 11          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 12          None  2024-10-26T13:56:00.000Z   1027.00000      Ethereum
# 13          None  2024-10-26T13:56:00.000Z          NaN           NaN
# 14          None  2024-10-26T13:56:00.000Z   1027.00000      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2024-10-26 16:59:12.687480
# 1  2024-10-26 16:59:12.687480
# 2  2024-10-26 16:59:12.687480
# 3  2024-10-26 16:59:12.687480
# 4  2024-10-26 16:59:12.687480
# 5  2024-10-26 16:59:12.687480
# 6  2024-10-26 16:59:12.687480
# 7  2024-10-26 16:59:12.687480
# 8  2024-10-26 16:59:12.687480
# 9  2024-10-26 16:59:12.687480
# 10 2024-10-26 16:59:12.687480
# 11 2024-10-26 16:59:12.687480
# 12 2024-10-26 16:59:12.687480
# 13 2024-10-26 16:59:12.687480
# 14 2024-10-26 16:59:12.687480

# %%
# Сoin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.12802                      -1.97091
# Ethereum                         -0.19118                      -3.22724
# Tether USDt                       0.00077                      -0.06859
# BNB                              -0.46581                      -1.96498
# Solana                           -0.49326                      -3.59591
# USDC                              0.00401                      -0.00571
# XRP                              -0.60530                      -2.63307
# Dogecoin                         -0.77769                      -3.39766
# TRON                              0.10928                      -1.05555
# Toncoin                          -0.52008                      -2.76016
# Cardano                          -0.57076                      -4.91495
# Avalanche                        -1.06524                      -4.58159
# Shiba Inu                        -0.80528                      -4.92836
# Bitcoin Cash                     -0.89142                      -5.96683
# Chainlink                        -1.04415                      -7.61640
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          -1.84291                       3.87670
# Ethereum                         -6.53284                      -5.92130
# Tether USDt                      -0.12456                      -0.14470
# BNB                              -2.70197                      -2.10157
# Solana                            8.54607                      10.76837
# USDC                             -0.01261                      -0.03350
# XRP                              -6.16037                     -13.26504
# Dogecoin                         -7.83657                      16.67654
# TRON                              4.49312                       8.11838
# Toncoin                          -6.54950                     -15.41111
# Cardano                          -6.35979                     -17.15621
# Avalanche                        -9.25501                     -11.14631
# Shiba Inu                       -12.34429                      -1.57097
# Bitcoin Cash                     -3.79759                      -0.07598
# Chainlink                        -3.36136                     -10.28861
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                            7.31217                      -1.69221
# Ethereum                          -5.75533                     -24.77925
# Tether USDt                       -0.13901                      -0.12132
# BNB                                4.40017                      -0.29956
# Solana                             8.48329                      -9.84496
# USDC                              -0.01820                      -0.00638
# XRP                              -13.99480                     -15.14284
# Dogecoin                          27.90774                       2.01946
# TRON                               2.21929                      19.82711
# Toncoin                          -10.61089                     -25.25705
# Cardano                          -10.07352                     -20.26207
# Avalanche                         -1.71454                      -8.37435
# Shiba Inu                         16.76062                      -0.59116
# Bitcoin Cash                       2.45049                     -12.45526
# Chainlink                         -5.55799                     -19.24227

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.12802
#               quote.USD.percent_change_24h    -1.97091
#               quote.USD.percent_change_7d     -1.84291
#               quote.USD.percent_change_30d     3.87670
#               quote.USD.percent_change_60d     7.31217
#               quote.USD.percent_change_90d    -1.69221
# Ethereum      quote.USD.percent_change_1h     -0.19118
#               quote.USD.percent_change_24h    -3.22724
#               quote.USD.percent_change_7d     -6.53284
#               quote.USD.percent_change_30d    -5.92130
#               quote.USD.percent_change_60d    -5.75533
#               quote.USD.percent_change_90d   -24.77925
# Tether USDt   quote.USD.percent_change_1h      0.00077
#               quote.USD.percent_change_24h    -0.06859
#               quote.USD.percent_change_7d     -0.12456
#               quote.USD.percent_change_30d    -0.14470
#               quote.USD.percent_change_60d    -0.13901
#               quote.USD.percent_change_90d    -0.12132
# BNB           quote.USD.percent_change_1h     -0.46581
#               quote.USD.percent_change_24h    -1.96498
#               quote.USD.percent_change_7d     -2.70197
#               quote.USD.percent_change_30d    -2.10157
#               quote.USD.percent_change_60d     4.40017
#               quote.USD.percent_change_90d    -0.29956
# Solana        quote.USD.percent_change_1h     -0.49326
#               quote.USD.percent_change_24h    -3.59591
#               quote.USD.percent_change_7d      8.54607
#               quote.USD.percent_change_30d    10.76837
#               quote.USD.percent_change_60d     8.48329
#               quote.USD.percent_change_90d    -9.84496
# USDC          quote.USD.percent_change_1h      0.00401
#               quote.USD.percent_change_24h    -0.00571
#               quote.USD.percent_change_7d     -0.01261
#               quote.USD.percent_change_30d    -0.03350
#               quote.USD.percent_change_60d    -0.01820
#               quote.USD.percent_change_90d    -0.00638
# XRP           quote.USD.percent_change_1h     -0.60530
#               quote.USD.percent_change_24h    -2.63307
#               quote.USD.percent_change_7d     -6.16037
#               quote.USD.percent_change_30d   -13.26504
#               quote.USD.percent_change_60d   -13.99480
#               quote.USD.percent_change_90d   -15.14284
# Dogecoin      quote.USD.percent_change_1h     -0.77769
#               quote.USD.percent_change_24h    -3.39766
#               quote.USD.percent_change_7d     -7.83657
#               quote.USD.percent_change_30d    16.67654
#               quote.USD.percent_change_60d    27.90774
#               quote.USD.percent_change_90d     2.01946
# TRON          quote.USD.percent_change_1h      0.10928
#               quote.USD.percent_change_24h    -1.05555
#               quote.USD.percent_change_7d      4.49312
#               quote.USD.percent_change_30d     8.11838
#               quote.USD.percent_change_60d     2.21929
#               quote.USD.percent_change_90d    19.82711
# Toncoin       quote.USD.percent_change_1h     -0.52008
#               quote.USD.percent_change_24h    -2.76016
#               quote.USD.percent_change_7d     -6.54950
#               quote.USD.percent_change_30d   -15.41111
#               quote.USD.percent_change_60d   -10.61089
#               quote.USD.percent_change_90d   -25.25705
# Cardano       quote.USD.percent_change_1h     -0.57076
#               quote.USD.percent_change_24h    -4.91495
#               quote.USD.percent_change_7d     -6.35979
#               quote.USD.percent_change_30d   -17.15621
#               quote.USD.percent_change_60d   -10.07352
#               quote.USD.percent_change_90d   -20.26207
# Avalanche     quote.USD.percent_change_1h     -1.06524
#               quote.USD.percent_change_24h    -4.58159
#               quote.USD.percent_change_7d     -9.25501
#               quote.USD.percent_change_30d   -11.14631
#               quote.USD.percent_change_60d    -1.71454
#               quote.USD.percent_change_90d    -8.37435
# Shiba Inu     quote.USD.percent_change_1h     -0.80528
#               quote.USD.percent_change_24h    -4.92836
#               quote.USD.percent_change_7d    -12.34429
#               quote.USD.percent_change_30d    -1.57097
#               quote.USD.percent_change_60d    16.76062
#               quote.USD.percent_change_90d    -0.59116
# Bitcoin Cash  quote.USD.percent_change_1h     -0.89142
#               quote.USD.percent_change_24h    -5.96683
#               quote.USD.percent_change_7d     -3.79759
#               quote.USD.percent_change_30d    -0.07598
#               quote.USD.percent_change_60d     2.45049
#               quote.USD.percent_change_90d   -12.45526
# Chainlink     quote.USD.percent_change_1h     -1.04415
#               quote.USD.percent_change_24h    -7.61640
#               quote.USD.percent_change_7d     -3.36136
#               quote.USD.percent_change_30d   -10.28861
#               quote.USD.percent_change_60d    -5.55799
#               quote.USD.percent_change_90d   -19.24227
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.12802
#              quote.USD.percent_change_24h  -1.97091
#              quote.USD.percent_change_7d   -1.84291
#              quote.USD.percent_change_30d   3.87670
#              quote.USD.percent_change_60d   7.31217
#              quote.USD.percent_change_90d  -1.69221
# Ethereum     quote.USD.percent_change_1h   -0.19118
#              quote.USD.percent_change_24h  -3.22724
#              quote.USD.percent_change_7d   -6.53284
#              quote.USD.percent_change_30d  -5.92130
#              quote.USD.percent_change_60d  -5.75533
#              quote.USD.percent_change_90d -24.77925
# Tether USDt  quote.USD.percent_change_1h    0.00077
#              quote.USD.percent_change_24h  -0.06859
#              quote.USD.percent_change_7d   -0.12456
#              quote.USD.percent_change_30d  -0.14470
#              quote.USD.percent_change_60d  -0.13901
#              quote.USD.percent_change_90d  -0.12132
# BNB          quote.USD.percent_change_1h   -0.46581
#              quote.USD.percent_change_24h  -1.96498
#              quote.USD.percent_change_7d   -2.70197
#              quote.USD.percent_change_30d  -2.10157
#              quote.USD.percent_change_60d   4.40017
#              quote.USD.percent_change_90d  -0.29956
# Solana       quote.USD.percent_change_1h   -0.49326
#              quote.USD.percent_change_24h  -3.59591
#              quote.USD.percent_change_7d    8.54607
#              quote.USD.percent_change_30d  10.76837
#              quote.USD.percent_change_60d   8.48329
#              quote.USD.percent_change_90d  -9.84496
# USDC         quote.USD.percent_change_1h    0.00401
#              quote.USD.percent_change_24h  -0.00571
#              quote.USD.percent_change_7d   -0.01261
#              quote.USD.percent_change_30d  -0.03350
#              quote.USD.percent_change_60d  -0.01820
#              quote.USD.percent_change_90d  -0.00638
# XRP          quote.USD.percent_change_1h   -0.60530
#              quote.USD.percent_change_24h  -2.63307
#              quote.USD.percent_change_7d   -6.16037
#              quote.USD.percent_change_30d -13.26504
#              quote.USD.percent_change_60d -13.99480
#              quote.USD.percent_change_90d -15.14284
# Dogecoin     quote.USD.percent_change_1h   -0.77769
#              quote.USD.percent_change_24h  -3.39766
#              quote.USD.percent_change_7d   -7.83657
#              quote.USD.percent_change_30d  16.67654
#              quote.USD.percent_change_60d  27.90774
#              quote.USD.percent_change_90d   2.01946
# TRON         quote.USD.percent_change_1h    0.10928
#              quote.USD.percent_change_24h  -1.05555
#              quote.USD.percent_change_7d    4.49312
#              quote.USD.percent_change_30d   8.11838
#              quote.USD.percent_change_60d   2.21929
#              quote.USD.percent_change_90d  19.82711
# Toncoin      quote.USD.percent_change_1h   -0.52008
#              quote.USD.percent_change_24h  -2.76016
#              quote.USD.percent_change_7d   -6.54950
#              quote.USD.percent_change_30d -15.41111
#              quote.USD.percent_change_60d -10.61089
#              quote.USD.percent_change_90d -25.25705
# Cardano      quote.USD.percent_change_1h   -0.57076
#              quote.USD.percent_change_24h  -4.91495
#              quote.USD.percent_change_7d   -6.35979
#              quote.USD.percent_change_30d -17.15621
#              quote.USD.percent_change_60d -10.07352
#              quote.USD.percent_change_90d -20.26207
# Avalanche    quote.USD.percent_change_1h   -1.06524
#              quote.USD.percent_change_24h  -4.58159
#              quote.USD.percent_change_7d   -9.25501
#              quote.USD.percent_change_30d -11.14631
#              quote.USD.percent_change_60d  -1.71454
#              quote.USD.percent_change_90d  -8.37435
# Shiba Inu    quote.USD.percent_change_1h   -0.80528
#              quote.USD.percent_change_24h  -4.92836
#              quote.USD.percent_change_7d  -12.34429
#              quote.USD.percent_change_30d  -1.57097
#              quote.USD.percent_change_60d  16.76062
#              quote.USD.percent_change_90d  -0.59116
# Bitcoin Cash quote.USD.percent_change_1h   -0.89142
#              quote.USD.percent_change_24h  -5.96683
#              quote.USD.percent_change_7d   -3.79759
#              quote.USD.percent_change_30d  -0.07598
#              quote.USD.percent_change_60d   2.45049
#              quote.USD.percent_change_90d -12.45526
# Chainlink    quote.USD.percent_change_1h   -1.04415
#              quote.USD.percent_change_24h  -7.61640
#              quote.USD.percent_change_7d   -3.36136
#              quote.USD.percent_change_30d -10.28861
#              quote.USD.percent_change_60d  -5.55799
#              quote.USD.percent_change_90d -19.24227

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
# Set the DataFrame index object as the index

index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#             name                       level_1    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.12802
# 1        Bitcoin  quote.USD.percent_change_24h  -1.97091
# 2        Bitcoin   quote.USD.percent_change_7d  -1.84291
# 3        Bitcoin  quote.USD.percent_change_30d   3.87670
# 4        Bitcoin  quote.USD.percent_change_60d   7.31217
# 5        Bitcoin  quote.USD.percent_change_90d  -1.69221
# 6       Ethereum   quote.USD.percent_change_1h  -0.19118
# 7       Ethereum  quote.USD.percent_change_24h  -3.22724
# 8       Ethereum   quote.USD.percent_change_7d  -6.53284
# 9       Ethereum  quote.USD.percent_change_30d  -5.92130
# 10      Ethereum  quote.USD.percent_change_60d  -5.75533
# 11      Ethereum  quote.USD.percent_change_90d -24.77925
# 12   Tether USDt   quote.USD.percent_change_1h   0.00077
# 13   Tether USDt  quote.USD.percent_change_24h  -0.06859
# 14   Tether USDt   quote.USD.percent_change_7d  -0.12456
# 15   Tether USDt  quote.USD.percent_change_30d  -0.14470
# 16   Tether USDt  quote.USD.percent_change_60d  -0.13901
# 17   Tether USDt  quote.USD.percent_change_90d  -0.12132
# 18           BNB   quote.USD.percent_change_1h  -0.46581
# 19           BNB  quote.USD.percent_change_24h  -1.96498
# 20           BNB   quote.USD.percent_change_7d  -2.70197
# 21           BNB  quote.USD.percent_change_30d  -2.10157
# 22           BNB  quote.USD.percent_change_60d   4.40017
# 23           BNB  quote.USD.percent_change_90d  -0.29956
# 24        Solana   quote.USD.percent_change_1h  -0.49326
# 25        Solana  quote.USD.percent_change_24h  -3.59591
# 26        Solana   quote.USD.percent_change_7d   8.54607
# 27        Solana  quote.USD.percent_change_30d  10.76837
# 28        Solana  quote.USD.percent_change_60d   8.48329
# 29        Solana  quote.USD.percent_change_90d  -9.84496
# 30          USDC   quote.USD.percent_change_1h   0.00401
# 31          USDC  quote.USD.percent_change_24h  -0.00571
# 32          USDC   quote.USD.percent_change_7d  -0.01261
# 33          USDC  quote.USD.percent_change_30d  -0.03350
# 34          USDC  quote.USD.percent_change_60d  -0.01820
# 35          USDC  quote.USD.percent_change_90d  -0.00638
# 36           XRP   quote.USD.percent_change_1h  -0.60530
# 37           XRP  quote.USD.percent_change_24h  -2.63307
# 38           XRP   quote.USD.percent_change_7d  -6.16037
# 39           XRP  quote.USD.percent_change_30d -13.26504
# 40           XRP  quote.USD.percent_change_60d -13.99480
# 41           XRP  quote.USD.percent_change_90d -15.14284
# 42      Dogecoin   quote.USD.percent_change_1h  -0.77769
# 43      Dogecoin  quote.USD.percent_change_24h  -3.39766
# 44      Dogecoin   quote.USD.percent_change_7d  -7.83657
# 45      Dogecoin  quote.USD.percent_change_30d  16.67654
# 46      Dogecoin  quote.USD.percent_change_60d  27.90774
# 47      Dogecoin  quote.USD.percent_change_90d   2.01946
# 48          TRON   quote.USD.percent_change_1h   0.10928
# 49          TRON  quote.USD.percent_change_24h  -1.05555
# 50          TRON   quote.USD.percent_change_7d   4.49312
# 51          TRON  quote.USD.percent_change_30d   8.11838
# 52          TRON  quote.USD.percent_change_60d   2.21929
# 53          TRON  quote.USD.percent_change_90d  19.82711
# 54       Toncoin   quote.USD.percent_change_1h  -0.52008
# 55       Toncoin  quote.USD.percent_change_24h  -2.76016
# 56       Toncoin   quote.USD.percent_change_7d  -6.54950
# 57       Toncoin  quote.USD.percent_change_30d -15.41111
# 58       Toncoin  quote.USD.percent_change_60d -10.61089
# 59       Toncoin  quote.USD.percent_change_90d -25.25705
# 60       Cardano   quote.USD.percent_change_1h  -0.57076
# 61       Cardano  quote.USD.percent_change_24h  -4.91495
# 62       Cardano   quote.USD.percent_change_7d  -6.35979
# 63       Cardano  quote.USD.percent_change_30d -17.15621
# 64       Cardano  quote.USD.percent_change_60d -10.07352
# 65       Cardano  quote.USD.percent_change_90d -20.26207
# 66     Avalanche   quote.USD.percent_change_1h  -1.06524
# 67     Avalanche  quote.USD.percent_change_24h  -4.58159
# 68     Avalanche   quote.USD.percent_change_7d  -9.25501
# 69     Avalanche  quote.USD.percent_change_30d -11.14631
# 70     Avalanche  quote.USD.percent_change_60d  -1.71454
# 71     Avalanche  quote.USD.percent_change_90d  -8.37435
# 72     Shiba Inu   quote.USD.percent_change_1h  -0.80528
# 73     Shiba Inu  quote.USD.percent_change_24h  -4.92836
# 74     Shiba Inu   quote.USD.percent_change_7d -12.34429
# 75     Shiba Inu  quote.USD.percent_change_30d  -1.57097
# 76     Shiba Inu  quote.USD.percent_change_60d  16.76062
# 77     Shiba Inu  quote.USD.percent_change_90d  -0.59116
# 78  Bitcoin Cash   quote.USD.percent_change_1h  -0.89142
# 79  Bitcoin Cash  quote.USD.percent_change_24h  -5.96683
# 80  Bitcoin Cash   quote.USD.percent_change_7d  -3.79759
# 81  Bitcoin Cash  quote.USD.percent_change_30d  -0.07598
# 82  Bitcoin Cash  quote.USD.percent_change_60d   2.45049
# 83  Bitcoin Cash  quote.USD.percent_change_90d -12.45526
# 84     Chainlink   quote.USD.percent_change_1h  -1.04415
# 85     Chainlink  quote.USD.percent_change_24h  -7.61640
# 86     Chainlink   quote.USD.percent_change_7d  -3.36136
# 87     Chainlink  quote.USD.percent_change_30d -10.28861
# 88     Chainlink  quote.USD.percent_change_60d  -5.55799
# 89     Chainlink  quote.USD.percent_change_90d -19.24227

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#             name                percent_change    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.12802
# 1        Bitcoin  quote.USD.percent_change_24h  -1.97091
# 2        Bitcoin   quote.USD.percent_change_7d  -1.84291
# 3        Bitcoin  quote.USD.percent_change_30d   3.87670
# 4        Bitcoin  quote.USD.percent_change_60d   7.31217
# 5        Bitcoin  quote.USD.percent_change_90d  -1.69221
# 6       Ethereum   quote.USD.percent_change_1h  -0.19118
# 7       Ethereum  quote.USD.percent_change_24h  -3.22724
# 8       Ethereum   quote.USD.percent_change_7d  -6.53284
# 9       Ethereum  quote.USD.percent_change_30d  -5.92130
# 10      Ethereum  quote.USD.percent_change_60d  -5.75533
# 11      Ethereum  quote.USD.percent_change_90d -24.77925
# 12   Tether USDt   quote.USD.percent_change_1h   0.00077
# 13   Tether USDt  quote.USD.percent_change_24h  -0.06859
# 14   Tether USDt   quote.USD.percent_change_7d  -0.12456
# 15   Tether USDt  quote.USD.percent_change_30d  -0.14470
# 16   Tether USDt  quote.USD.percent_change_60d  -0.13901
# 17   Tether USDt  quote.USD.percent_change_90d  -0.12132
# 18           BNB   quote.USD.percent_change_1h  -0.46581
# 19           BNB  quote.USD.percent_change_24h  -1.96498
# 20           BNB   quote.USD.percent_change_7d  -2.70197
# 21           BNB  quote.USD.percent_change_30d  -2.10157
# 22           BNB  quote.USD.percent_change_60d   4.40017
# 23           BNB  quote.USD.percent_change_90d  -0.29956
# 24        Solana   quote.USD.percent_change_1h  -0.49326
# 25        Solana  quote.USD.percent_change_24h  -3.59591
# 26        Solana   quote.USD.percent_change_7d   8.54607
# 27        Solana  quote.USD.percent_change_30d  10.76837
# 28        Solana  quote.USD.percent_change_60d   8.48329
# 29        Solana  quote.USD.percent_change_90d  -9.84496
# 30          USDC   quote.USD.percent_change_1h   0.00401
# 31          USDC  quote.USD.percent_change_24h  -0.00571
# 32          USDC   quote.USD.percent_change_7d  -0.01261
# 33          USDC  quote.USD.percent_change_30d  -0.03350
# 34          USDC  quote.USD.percent_change_60d  -0.01820
# 35          USDC  quote.USD.percent_change_90d  -0.00638
# 36           XRP   quote.USD.percent_change_1h  -0.60530
# 37           XRP  quote.USD.percent_change_24h  -2.63307
# 38           XRP   quote.USD.percent_change_7d  -6.16037
# 39           XRP  quote.USD.percent_change_30d -13.26504
# 40           XRP  quote.USD.percent_change_60d -13.99480
# 41           XRP  quote.USD.percent_change_90d -15.14284
# 42      Dogecoin   quote.USD.percent_change_1h  -0.77769
# 43      Dogecoin  quote.USD.percent_change_24h  -3.39766
# 44      Dogecoin   quote.USD.percent_change_7d  -7.83657
# 45      Dogecoin  quote.USD.percent_change_30d  16.67654
# 46      Dogecoin  quote.USD.percent_change_60d  27.90774
# 47      Dogecoin  quote.USD.percent_change_90d   2.01946
# 48          TRON   quote.USD.percent_change_1h   0.10928
# 49          TRON  quote.USD.percent_change_24h  -1.05555
# 50          TRON   quote.USD.percent_change_7d   4.49312
# 51          TRON  quote.USD.percent_change_30d   8.11838
# 52          TRON  quote.USD.percent_change_60d   2.21929
# 53          TRON  quote.USD.percent_change_90d  19.82711
# 54       Toncoin   quote.USD.percent_change_1h  -0.52008
# 55       Toncoin  quote.USD.percent_change_24h  -2.76016
# 56       Toncoin   quote.USD.percent_change_7d  -6.54950
# 57       Toncoin  quote.USD.percent_change_30d -15.41111
# 58       Toncoin  quote.USD.percent_change_60d -10.61089
# 59       Toncoin  quote.USD.percent_change_90d -25.25705
# 60       Cardano   quote.USD.percent_change_1h  -0.57076
# 61       Cardano  quote.USD.percent_change_24h  -4.91495
# 62       Cardano   quote.USD.percent_change_7d  -6.35979
# 63       Cardano  quote.USD.percent_change_30d -17.15621
# 64       Cardano  quote.USD.percent_change_60d -10.07352
# 65       Cardano  quote.USD.percent_change_90d -20.26207
# 66     Avalanche   quote.USD.percent_change_1h  -1.06524
# 67     Avalanche  quote.USD.percent_change_24h  -4.58159
# 68     Avalanche   quote.USD.percent_change_7d  -9.25501
# 69     Avalanche  quote.USD.percent_change_30d -11.14631
# 70     Avalanche  quote.USD.percent_change_60d  -1.71454
# 71     Avalanche  quote.USD.percent_change_90d  -8.37435
# 72     Shiba Inu   quote.USD.percent_change_1h  -0.80528
# 73     Shiba Inu  quote.USD.percent_change_24h  -4.92836
# 74     Shiba Inu   quote.USD.percent_change_7d -12.34429
# 75     Shiba Inu  quote.USD.percent_change_30d  -1.57097
# 76     Shiba Inu  quote.USD.percent_change_60d  16.76062
# 77     Shiba Inu  quote.USD.percent_change_90d  -0.59116
# 78  Bitcoin Cash   quote.USD.percent_change_1h  -0.89142
# 79  Bitcoin Cash  quote.USD.percent_change_24h  -5.96683
# 80  Bitcoin Cash   quote.USD.percent_change_7d  -3.79759
# 81  Bitcoin Cash  quote.USD.percent_change_30d  -0.07598
# 82  Bitcoin Cash  quote.USD.percent_change_60d   2.45049
# 83  Bitcoin Cash  quote.USD.percent_change_90d -12.45526
# 84     Chainlink   quote.USD.percent_change_1h  -1.04415
# 85     Chainlink  quote.USD.percent_change_24h  -7.61640
# 86     Chainlink   quote.USD.percent_change_7d  -3.36136
# 87     Chainlink  quote.USD.percent_change_30d -10.28861
# 88     Chainlink  quote.USD.percent_change_60d  -5.55799
# 89     Chainlink  quote.USD.percent_change_90d -19.24227

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#             name percent_change    values
# 0        Bitcoin             1h  -0.12802
# 1        Bitcoin            24h  -1.97091
# 2        Bitcoin             7d  -1.84291
# 3        Bitcoin            30d   3.87670
# 4        Bitcoin            60d   7.31217
# 5        Bitcoin            90d  -1.69221
# 6       Ethereum             1h  -0.19118
# 7       Ethereum            24h  -3.22724
# 8       Ethereum             7d  -6.53284
# 9       Ethereum            30d  -5.92130
# 10      Ethereum            60d  -5.75533
# 11      Ethereum            90d -24.77925
# 12   Tether USDt             1h   0.00077
# 13   Tether USDt            24h  -0.06859
# 14   Tether USDt             7d  -0.12456
# 15   Tether USDt            30d  -0.14470
# 16   Tether USDt            60d  -0.13901
# 17   Tether USDt            90d  -0.12132
# 18           BNB             1h  -0.46581
# 19           BNB            24h  -1.96498
# 20           BNB             7d  -2.70197
# 21           BNB            30d  -2.10157
# 22           BNB            60d   4.40017
# 23           BNB            90d  -0.29956
# 24        Solana             1h  -0.49326
# 25        Solana            24h  -3.59591
# 26        Solana             7d   8.54607
# 27        Solana            30d  10.76837
# 28        Solana            60d   8.48329
# 29        Solana            90d  -9.84496
# 30          USDC             1h   0.00401
# 31          USDC            24h  -0.00571
# 32          USDC             7d  -0.01261
# 33          USDC            30d  -0.03350
# 34          USDC            60d  -0.01820
# 35          USDC            90d  -0.00638
# 36           XRP             1h  -0.60530
# 37           XRP            24h  -2.63307
# 38           XRP             7d  -6.16037
# 39           XRP            30d -13.26504
# 40           XRP            60d -13.99480
# 41           XRP            90d -15.14284
# 42      Dogecoin             1h  -0.77769
# 43      Dogecoin            24h  -3.39766
# 44      Dogecoin             7d  -7.83657
# 45      Dogecoin            30d  16.67654
# 46      Dogecoin            60d  27.90774
# 47      Dogecoin            90d   2.01946
# 48          TRON             1h   0.10928
# 49          TRON            24h  -1.05555
# 50          TRON             7d   4.49312
# 51          TRON            30d   8.11838
# 52          TRON            60d   2.21929
# 53          TRON            90d  19.82711
# 54       Toncoin             1h  -0.52008
# 55       Toncoin            24h  -2.76016
# 56       Toncoin             7d  -6.54950
# 57       Toncoin            30d -15.41111
# 58       Toncoin            60d -10.61089
# 59       Toncoin            90d -25.25705
# 60       Cardano             1h  -0.57076
# 61       Cardano            24h  -4.91495
# 62       Cardano             7d  -6.35979
# 63       Cardano            30d -17.15621
# 64       Cardano            60d -10.07352
# 65       Cardano            90d -20.26207
# 66     Avalanche             1h  -1.06524
# 67     Avalanche            24h  -4.58159
# 68     Avalanche             7d  -9.25501
# 69     Avalanche            30d -11.14631
# 70     Avalanche            60d  -1.71454
# 71     Avalanche            90d  -8.37435
# 72     Shiba Inu             1h  -0.80528
# 73     Shiba Inu            24h  -4.92836
# 74     Shiba Inu             7d -12.34429
# 75     Shiba Inu            30d  -1.57097
# 76     Shiba Inu            60d  16.76062
# 77     Shiba Inu            90d  -0.59116
# 78  Bitcoin Cash             1h  -0.89142
# 79  Bitcoin Cash            24h  -5.96683
# 80  Bitcoin Cash             7d  -3.79759
# 81  Bitcoin Cash            30d  -0.07598
# 82  Bitcoin Cash            60d   2.45049
# 83  Bitcoin Cash            90d -12.45526
# 84     Chainlink             1h  -1.04415
# 85     Chainlink            24h  -7.61640
# 86     Chainlink             7d  -3.36136
# 87     Chainlink            30d -10.28861
# 88     Chainlink            60d  -5.55799
# 89     Chainlink            90d -19.24227

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      66856.02291 2024-10-26 16:59:12.687480

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
